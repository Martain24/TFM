# %%
import requests 
URL_BACKEND = "http://127.0.0.1:8000/"  
response = requests.post(url=f"{URL_BACKEND}login",
                         data={"username": "vilaboamartin@gmail.com", "password": "vilaboa"})
headers = {"Authorization": f"{response.json()['token_type']} {response.json()['access_token']}"}
headers
# Out:
# {'Authorization': 'bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjozLCJleHAiOjE3MTY3NDU3MjR9.RdtdejGlJWkCNcPeBkX6M2bcQ5ZXI6bp6akr0oNutkw'}

# %%
input_data = {
    1: {
        "age": 30,
        "education": "hola",
        "marital_status": "hola",
        "income": 40000,
        "kidhome": 2,
        "teenhome": 1,
        "year_customer_entered": "2013",
        "recency": 50,
        "complain": 1
    },
    2: {
        "age": 50,
        "education": "phd",
        "marital_status": "Single",
        "income": 30000,
        "kidhome": 0,
        "teenhome": 0,
        "year_customer_entered": "2013",
        "recency": 10,
        "complain": 0
    }
}
response = requests.post(url=f"{URL_BACKEND}predictions/best_model_fruits",
                         headers=headers, json=input_data)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'id': 26,
#  'user': {'id': 3,
#   'name': 'Martín ',
#   'surname': 'Vilaboa García',
#   'email': 'vilaboamartin@gmail.com',
#   'created_at': '2024-05-23T17:33:58.515640+02:00',
#   'is_confirmed': True},
#  'ml_model': {'title': 'Frutas',
#   'short_description': 'Modelo para predecir la cantidad de fruta',
#   'filename_of_model': 'best_model_fruits'},
#  'prediction_input': {'1': {'age': 30,
#    'education': 'hola',
#    'marital_status': 'hola',
#    'income': 40000,
#    'kidhome': 2,
#    'teenhome': 1,
#    'year_customer_entered': '2013',
#    'recency': 50,
#    'complain': 1},
#   '2': {'age': 50,
#    'education': 'PhD',
#    'marital_status': 'Single',
#    'income': 30000,
#    'kidhome': 0,
#    'teenhome': 0,
#    'year_customer_entered': '2013',
#    'recency': 10,
#    'complain': 0}},
#  'prediction_output': {'1': {'predicted_MntFruitsProducts': '29.43419'},
#   '2': {'predicted_MntFruitsProducts': '38.004505'}},
#  'created_at': '2024-05-26T19:18:53.428326+02:00'}

# %%
import pandas as pd
input_data = {
    1: {
        "age": 2,
        "marital_status": "married"
    },
    2: {
       "age": 30,
       "marital_status": "alone" 
    }
}

pd.DataFrame(input_data).T
# Out:
#   age marital_status
# 1   2        married
# 2  30          alone

# %%
from pydantic import BaseModel, EmailStr
class hola(BaseModel):
    saludo: str 
    edad: int 

hola(saludo=5, edad=3)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 6
#       3     saludo: str
#       4     edad: int
# ----> 6 hola(saludo=5, edad=3)
#
# File ~/miniforge3/envs/entorno_general/lib/python3.11/site-packages/pydantic/main.py:176, in BaseModel.__init__(self, **data)
#     174 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     175 __tracebackhide__ = True
# --> 176 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 1 validation error for hola
# saludo
#   Input should be a valid string [type=string_type, input_value=5, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type

# %%
import os
os.path.join("adios", f"sav_models/{'hola'.split('.')[0]}/{'hola'}")
# Out:
# 'adios/sav_models/hola/hola'

# %%
import requests

# URL de la ruta donde se crea un nuevo usuario
url = "http://127.0.0.1:8000/users/"

# Datos del nuevo usuario a crear
new_user_data = {
    "email": "hola@example.com",
    "password": "hola",
    # Otros campos del usuario, si los hay
}

# Realizar la solicitud POST con los datos del nuevo usuario
response = requests.post(url, json=new_user_data)

# Verificar el código de estado de la respuesta
if response.status_code == 201:
    # El usuario fue creado exitosamente
    new_user = response.json()
    print("Nuevo usuario creado:", new_user)
else:
    # Hubo un error al crear el usuario
    print("Error al crear el usuario:", response.json())
# Out:
# Nuevo usuario creado: {'id': 17, 'email': 'hola1111@example.com', 'created_at': '2024-05-08T20:46:02.272679+02:00', 'is_vip': False}

# %%
import requests
url = "http://127.0.0.1:8000/users/"
response = requests.put(url, headers={"Authorization": f"bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoxLCJleHAiOjE3MTYzMDg4NzR9.wT8RzFcNdVA9m0YBQzoloV48AEX53tydN-j6nacNxeY"}).json()
response
# Out:
# {'id': 1,
#  'name': 'Martin',
#  'surname': 'Vilaboa',
#  'email': 'vilaboamartin@gmail.com',
#  'created_at': '2024-05-21T17:57:54.113820+02:00',
#  'is_confirmed': True}

# %%
import requests
url = "http://127.0.0.1:8000/users/login/"
response = requests.post(url, json={"email": "vilaboamartin@gmail.com", "password": "vilaboa"}).json()
headers = {"Authorization": f"{response['token_type']} {response['access_token']}"}
headers
# Out:
# {'Authorization': 'bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjozLCJleHAiOjE3MTYzMDE1MTl9.XqLNynO6tAFYOd9nThFCjihLSlKTi3XKd0Nc8D3zeDo'}

# %%
import requests

# URL base de tu API
base_url = "http://127.0.0.1:8000/articles"

# Ruta para crear un nuevo artículo
create_article_url = base_url + "/"

# Datos del artículo a crear
new_article_data = {
    "title": "Logistic regression test",
    "short_description": "Un pequeño modelo para hacer testeo en dev",
    "filename_of_model": "logistic_test_model.sav"
}

# Realizar la solicitud POST con los datos del nuevo artículo
response = requests.post(create_article_url, json=new_article_data, headers=headers)

# Verificar el estado de la respuesta
if response.status_code == 201:
    # Obtener el artículo creado desde la respuesta JSON
    created_article = response.json()
    print("Artículo creado exitosamente:", created_article)
else:
    print("Error en la solicitud:", response.status_code)
    print("Detalle del error:", response.text)
# Out:
# Error en la solicitud: 406
# Detalle del error: {"detail":"The filename of the model is already in use."}

# %%
import requests

# URL base de tu API
base_url = "http://127.0.0.1:8000/predictions/"

# Ruta para la predicción logística
predict_url = base_url + "logistic_test_model/"

# Datos de entrada para la predicción
input_data = {
    "age": 30,
    "work_experience": 5,
    "gender": "Male",
    "graduated": "Yes",
    "ever_married": "no",
    "profession": "Engineer"
}

# Realizar la solicitud POST con los datos de entrada
response = requests.post(predict_url, json=input_data, headers=headers)

response.json()
# Out:
# {'user': {'id': 3,
#   'email': 'vilaboamartin@gmail.com',
#   'created_at': '2024-05-14T17:54:04.470985+02:00',
#   'is_confirmed': True},
#  'article': {'title': 'Logistic Test Model',
#   'short_description': 'Modelo de regresión logística para hacer pruebas',
#   'filename_of_model': 'logistic_test_model.sav'},
#  'prediction_input': {'Age': 30,
#   'Work_Experience': 5.0,
#   'Gender_Female': False,
#   'Gender_Male': True,
#   'Ever_Married_No': True,
#   'Ever_Married_Yes': False,
#   'Graduated_No': False,
#   'Graduated_Yes': True,
#   'Profession_Artist': False,
#   'Profession_Doctor': False,
#   'Profession_Engineer': True,
#   'Profession_Entertainment': False,
#   'Profession_Executive': False,
#   'Profession_Healthcare': False,
#   'Profession_Homemaker': False,
#   'Profession_Lawyer': False,
#   'Profession_Marketing': False},
#  'prediction_output': {'predicted_salary': 'Low'}}

# %%
response = requests.get("http://127.0.0.1:8000/predictions/", headers=headers).json()
response
# Out:
# [{'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 10.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': True,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 50,
#    'Work_Experience': 3.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 35,
#    'Work_Experience': 15.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': True,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 60,
#    'Work_Experience': 8.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': True,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 40,
#    'Work_Experience': 11.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': True,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 20.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': True,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 18,
#    'Work_Experience': 10.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': True,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 10.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': True,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 50,
#    'Work_Experience': 3.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 35,
#    'Work_Experience': 15.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': True,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 60,
#    'Work_Experience': 8.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': True,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 40,
#    'Work_Experience': 11.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': True,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 20.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': True,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 18,
#    'Work_Experience': 10.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': True,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 33,
#    'Work_Experience': 6.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 10.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': True,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 50,
#    'Work_Experience': 3.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 35,
#    'Work_Experience': 15.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': True,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 60,
#    'Work_Experience': 8.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': True,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 40,
#    'Work_Experience': 11.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': True,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 20.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': True,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 18,
#    'Work_Experience': 10.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': True,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 10.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': True,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 50,
#    'Work_Experience': 3.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 35,
#    'Work_Experience': 15.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': True,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 60,
#    'Work_Experience': 8.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': True,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 40,
#    'Work_Experience': 11.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': True,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 20.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': True,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 18,
#    'Work_Experience': 10.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': True,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 10.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': True,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': True,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 50,
#    'Work_Experience': 3.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 35,
#    'Work_Experience': 15.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': False,
#    'Ever_Married_Yes': True,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': True,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Average'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 60,
#    'Work_Experience': 8.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': True,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 40,
#    'Work_Experience': 11.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': True,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 20,
#    'Work_Experience': 20.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': True,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 18,
#    'Work_Experience': 10.0,
#    'Gender_Female': True,
#    'Gender_Male': False,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': True,
#    'Graduated_Yes': False,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': False,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': True,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}},
#  {'user': {'id': 3,
#    'email': 'vilaboamartin@gmail.com',
#    'created_at': '2024-05-14T17:54:04.470985+02:00',
#    'is_confirmed': True},
#   'article': {'title': 'Logistic Test Model',
#    'short_description': 'Modelo de regresión logística para hacer pruebas',
#    'filename_of_model': 'logistic_test_model.sav'},
#   'prediction_input': {'Age': 30,
#    'Work_Experience': 5.0,
#    'Gender_Female': False,
#    'Gender_Male': True,
#    'Ever_Married_No': True,
#    'Ever_Married_Yes': False,
#    'Graduated_No': False,
#    'Graduated_Yes': True,
#    'Profession_Artist': False,
#    'Profession_Doctor': False,
#    'Profession_Engineer': True,
#    'Profession_Entertainment': False,
#    'Profession_Executive': False,
#    'Profession_Healthcare': False,
#    'Profession_Homemaker': False,
#    'Profession_Lawyer': False,
#    'Profession_Marketing': False},
#   'prediction_output': {'predicted_salary': 'Low'}}]

# %%
import requests

# URL base de tu API
url = "http://127.0.0.1:8000/users/"

# ID del usuario que quieres borrar del mundo
user_id = 
#Realizamos la solicitud de delete
response = requests.delete(url + str(user_id), headers=headers)

# Verificar el estado de la respuesta
if response.status_code == 200:
    # Code 200 todo un éxito
    print("Usuario eliminado exitosamente.")
else:
    # ERROR
    print("Error al eliminar el usuario:", response.json())
# Out:
# Usuario eliminado exitosamente.

# %%
import smtplib
from email.mime.text import MIMEText

subject = "Email Subject"
body = "This is the body of the text message"
sender = "miluma082@gmail.com"
recipients = ["vilaboamartin@gmail.com"]
password = "aard nizv nivr roro"


def send_email(subject, body, sender, recipients, password):
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
       smtp_server.login(sender, password)
       smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")


send_email(subject, body, sender, recipients, password)
# Out:
# Message sent!
